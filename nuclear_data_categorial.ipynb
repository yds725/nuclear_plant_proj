# %% [markdown]
# <a href="https://colab.research.google.com/github/yds725/nuclear_plant_proj/blob/code_development/nuclear_data_categorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import re
import glob
import pandas as pd
import numpy as np
from pprint import pprint
import time

# %%
# 각 칼럼을 4분위로 해 카테고리화해 나누어준다
def iqr_quartile(data_f):
  
  for i in range(1, data_f.shape[1]):

    q1,q2,q3 = np.percentile(data_f.iloc[:,i], [25,50,75] )
    data_f.loc[data_f.iloc[:,i] <= q1, data_f.columns[i]] = 0
    data_f.loc[(data_f.iloc[:,i] > q1) & (data_f.iloc[:,i] <= q2), data_f.columns[i]] = 1
    data_f.loc[(data_f.iloc[:,i]> q2) & (data_f.iloc[:,i] <= q3), data_f.columns[i]] = 2
    data_f.loc[data_f.iloc[:,i] > q3, data_f.columns[i]] = 3

# 각 칼럼을 메디안으로 해 0과 1로 나눠줌
def split_median(data_f):
  for col in data_f.columns[1:]:
    median_1 = data_f[col].median()

    #print(median_1)

    data_f.loc[data_f[col] >= median_1, col ]= 1
    data_f.loc[data_f[col] != 1, col ] = 0
    
# 문자열이 있는 지 아닌지 확인
def check_if_string(data_f):
    for col in data_f00_cp.columns[1:]:
    #print(col)

        if data_f00_cp[col].dtype != np.number:
            return True
        else:# print('String')
            pass# print('Not string')

# %%
data_f00 = pd.read_csv("/content/drive/My Drive/Nuclear_SemiProj/data/train-002/0.csv")

data_f00_cp = data_f00.copy()

#print(data_f00_cp.median())

#median_list = data_f00_cp[1:].apply(pd.DataFrame.median)

#print(median_list)

#data_f00_cp[data_f00_cp[1:] >= median_list, data_f00_cp[1:]] = 1

#cols_to_drop = n_unique[n_unique == 1].index

for col in data_f00_cp.columns[1:]:
    #print(col)

    if data_f00_cp[col].dtype != np.number:
        print('String')
    else:
        print('Not string')


#iqr_quartile(data_f00_cp)

#pprint(data_f00_cp)



#data_f00 = p

#pd.

# %%
#start = time.time() # 시간 저장

# glob glob
train_csv_files = [file for file in glob.glob("/content/drive/My Drive/Nuclear_SemiProj/data/train-002/*.csv")]

# train_dic = {}

#dic_idx = -1
# 각 csv 파일

what_list = []

flagged = False

for file_name in train_csv_files:
    print(file_name)
    # csv 파일
    #dic_idx += 1
    train_csv = pd.read_csv(file_name)

    # 눌 데이터가 있는 지 확인
    flagged = check_if_string(train_csv) 

    if flagged:
      what_list.append(file_name)


print(what_list)
# Out:
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/0.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/1.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/10.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/100.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/101.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/102.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/103.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/104.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/105.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/106.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/107.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/108.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/109.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/11.csv
# /content/drive/My Drive/Nuclear_SemiProj/data/train-002/110.csv
# ...

# %%
# good
# for i in range(1,df_00.shape[1]):
#     q1,q2,q3 = np.percentile(df_00.iloc[:,i],[25,50,75])
#     df_00.loc[df_00.iloc[:,i] <= q1, df_00.columns[i]] = 0
#     df_00.loc[(df_00.iloc[:,i] > q1) & (df_00.iloc[:,i] <= q2), df_00.columns[i]] = 1
#     df_00.loc[(df_00.iloc[:,i]> q2) & (df_00.iloc[:,i] <= q3), df_00.columns[i]] = 2
#     df_00.loc[df_00.iloc[:,i] > q3, df_00.columns[i]] = 3
# print(df_00)

# %%
# print(data_f00_cp.columns[1:])

# print(data_f00_cp["V0000"].median())
# Out:
# Index(['V0000', 'V0001', 'V0002', 'V0003', 'V0004', 'V0005', 'V0006', 'V0007',
#        'V0009', 'V0011',
#        ...
#        'V5086', 'V5087', 'V5088', 'V5089', 'V5090', 'V5115', 'V5116', 'V5117',
#        'V5118', 'V5120'],
#       dtype='object', length=2309)
# 30.470234488146488
